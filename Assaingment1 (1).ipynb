# %% [markdown]
# **To perform descriptive analytics, visualize data distributions, and preprocess the dataset for further analysis.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-78b4985b-55d8-4100-9283-b7d883a0e3ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78b4985b-55d8-4100-9283-b7d883a0e3ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('diamonds.csv')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
print(df.describe())
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB
# None

# %%
#Visualize data distributions
sns.histplot(df['price'])
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
# Preprocess the dataset
for col in df.select_dtypes(include=np.number).columns:
    df[col].fillna(df[col].mean(), inplace=True)

# %%
df[col]
# Out:
# 0        2.43
# 1        2.31
# 2        2.31
# 3        2.63
# 4        2.75
#          ...
# 53935    3.50
# 53936    3.61
# 53937    3.56
# 53938    3.74
# 53939    3.64
# Name: z, Length: 53940, dtype: float64

# %% [markdown]
# **Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.
# Steps:
# Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).
# Identify numerical columns in the dataset.
# Calculate the mean, median, mode, and standard deviation for these columns.
# Provide a brief interpretation of these statistics.

# %%
numerical_cols = df.select_dtypes(include=np.number).columns
for col in numerical_cols:
    mean = df[col].mean()
    median = df[col].median()
    mode = df[col].mode()[0]
    std = df[col].std()
    print(f"Statistics for column '{col}':")
    print(f"  Mean: {mean}")
    print(f"  Median: {median}")
    print(f"  Mode: {mode}")
    print(f"  Standard Deviation: {std}")
# Out:
# Statistics for column 'carat':
#   Mean: 0.7979397478680014
#   Median: 0.7
#   Mode: 0.3
#   Standard Deviation: 0.4740112444054184
# Statistics for column 'depth':
#   Mean: 61.749404894327036
#   Median: 61.8
#   Mode: 62.0
#   Standard Deviation: 1.432621318833661
# Statistics for column 'table':
#   Mean: 57.45718390804598
#   Median: 57.0
#   Mode: 56.0
#   Standard Deviation: 2.2344905628213225
# Statistics for column 'price':
#   Mean: 3932.799721913237
#   Median: 2401.0
#   Mode: 605
#   Standard Deviation: 3989.439738146379
# Statistics for column 'x':
#   Mean: 5.731157211716722
#   Median: 5.7
#   Mode: 4.37
#   Standard Deviation: 1.1217607467924928
# Statistics for column 'y':
#   Mean: 5.734525954764553
#   Median: 5.71
#   Mode: 4.34
#   Standard Deviation: 1.1421346741235552
# Statistics for column 'z':
#   Mean: 3.5387337782721544
#   Median: 3.53
#   Mode: 2.7
#   Standard Deviation: 0.7056988469499941

# %% [markdown]
# **Data Visualization
# Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.
# **

# %%
numerical_cols = df.select_dtypes(include=np.number).columns
for col in numerical_cols:
    plt.figure() # Create a new figure for each plot
    sns.histplot(df[col])
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# Create boxplots for numerical variables to identify outliers and the interquartile range.
# Discuss any findings, such as extreme values or unusual distributions.

# %%
for col in numerical_cols:
    plt.figure()
    sns.boxplot(df[col])
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Bar Chart Analysis for Categorical Column:
# Identify categorical columns in the dataset.
# Create bar charts to visualize the frequency or count of each category.
# Analyze the distribution of categories and provide insights.
# ** **bold text**

# %%
categorical_cols = df.select_dtypes(include='object').columns
print(categorical_cols)
# Out:
# Index([], dtype='object')

# %%
for col in categorical_cols:
    plt.figure()
    df[col].value_counts().plot(kind='bar')
    plt.title(f"Bar Chart of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Standardization of Numerical Variables
# Objective: To scale numerical variables for uniformity, improving the dataset’s suitability for analytical models.
# Steps:
# Explain the concept of standardization (z-score normalization).
# Standardize the numerical columns using the formula: z=x-mu/sigma
#
#
# ​Show before and after comparisons of the data distributions.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
numerical_cols = df.select_dtypes(include=np.number).columns
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
for col in numerical_cols:
    plt.figure(figsize=(10, 4))

    plt.subplot(1, 2, 1)
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col} (Before Standardization)")

    plt.subplot(1, 2, 2)
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col} (After Standardization)")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Conversion of Categorical Data into Dummy Variables
# Objective: To transform categorical variables into a format that can be provided to ML algorithms.
# Steps:
# Discuss the need for converting categorical data into dummy
# variables (one-hot encoding).
# Apply one-hot encoding to the categorical columns, creating binary (0 or 1) columns for each category.
# Display a portion of the transformed dataset

# %%
import pandas as pd
df = pd.get_dummies(df, columns=['cut', 'color', 'clarity'])
print(df.head())
# Out:
#       carat     depth     table     price         x         y         z  \
# 0 -1.198168 -0.174092 -1.099672 -0.904095 -1.587837 -1.536196 -1.571129
# 1 -1.240361 -1.360738  1.585529 -0.904095 -1.641325 -1.658774 -1.741175
# 2 -1.198168 -3.385019  3.375663 -0.903844 -1.498691 -1.457395 -1.741175
# 3 -1.071587  0.454133  0.242928 -0.902090 -1.364971 -1.317305 -1.287720
# 4 -1.029394  1.082358  0.242928 -0.901839 -1.240167 -1.212238 -1.117674
#
#    cut_Fair  cut_Good  cut_Ideal  ...  color_I  color_J  clarity_I1  \
# 0     False     False       True  ...    False    False       False
# 1     False     False      False  ...    False    False       False
# 2     False      True      False  ...    False    False       False
# 3     False     False      False  ...     True    False       False
# 4     False      True      False  ...    False     True       False
#
#    clarity_IF  clarity_SI1  clarity_SI2  clarity_VS1  clarity_VS2  \
# ...

# %% [markdown]
# Conclusion
#
# Summarize the key findings from the descriptive analytics and data visualizations.
# Reflect on the importance of data preprocessing steps like standardization and one-hot encoding in data analysis and machine learning.

# %%
# prompt: solve conclusion

print("Conclusion:")
print("-" * 20)
print("This analysis provided insights into the Diamonds dataset, revealing the distribution and relationships between various attributes.")
print("Descriptive statistics helped understand the central tendency, spread, and overall shape of the numerical data.")
print("Visualizations like histograms and boxplots allowed for identifying outliers and understanding the distribution of data.")
print("Analyzing categorical variables through bar charts provided insights into the frequency of different categories.")
print("Data preprocessing steps like standardization and one-hot encoding are crucial for preparing the data for machine learning algorithms.")
print("Standardization ensures that all numerical features have a similar scale, preventing features with larger values from dominating the model.")
print("One-hot encoding converts categorical variables into numerical representations that algorithms can understand.")
print("This preprocessed dataset is now ready for further analysis and machine learning tasks.")
# Out:
# Conclusion:
# --------------------
# This analysis provided insights into the Diamonds dataset, revealing the distribution and relationships between various attributes.
# Descriptive statistics helped understand the central tendency, spread, and overall shape of the numerical data.
# Visualizations like histograms and boxplots allowed for identifying outliers and understanding the distribution of data.
# Analyzing categorical variables through bar charts provided insights into the frequency of different categories.
# Data preprocessing steps like standardization and one-hot encoding are crucial for preparing the data for machine learning algorithms.
# Standardization ensures that all numerical features have a similar scale, preventing features with larger values from dominating the model.
# One-hot encoding converts categorical variables into numerical representations that algorithms can understand.
# ...
